# %% [markdown]
# <a href="https://colab.research.google.com/github/nbarc888/test-run-for-507/blob/main/epidem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sqlalchemy import create_engine
import seaborn
import matplotlib.pyplot as plt
import sqlite3

# %%
# !pip freeze > packages.text

# %% [markdown]
# above commant creates the list into a text file under specific name

# %%
## data source
# https://catalog.data.gov/dataset/county-expenditures-by-category-fiscal-year-2010

data = pd.read_csv('maryland.csv')
data
# Out:
#               County  General Government  Public Safety  Public Works  \
# 0           Allegany                 3.1            6.8          12.2
# 1       Anne Arundel                 5.4           12.2          11.6
# 2     Baltimore City                 5.7           14.3          16.7
# 3   Baltimore County                 4.8           11.8          11.7
# 4            Calvert                 4.0            7.3           8.1
# 5           Caroline                 3.0            7.7           2.8
# 6            Carroll                 6.2            5.4           6.5
# 7              Cecil                 3.9            9.0           7.0
# 8            Charles                 6.4           13.1           7.7
# 9         Dorchester                10.4            8.7           7.0
# 10         Frederick                 4.4           10.2           8.5
# 11           Garrett                 4.4            6.3          19.0
# ...

# %%
## create blank sqlite db with name

sqlite3.connect('mayland2010.db')

# %%
conn = create_engine('sqlite:///mayland2010.db')
conn
# Out:
# Engine(sqlite:///mayland2010.db)

# %%
data.to_sql('fiscal2010', conn, if_exists='replace', index=False)
# Out:
# 25

# %%
sql_query1 = "select * from fiscal2010 where county like 'Harford';"
response = pd.read_sql_query(sql_query1, conn)
response
# Out:
#     County  General Government  Public Safety  Public Works  \
# 0  Harford                 9.6            9.6           9.1
#
#    Health/Social Services  Education/Libraries  Parks & Recreation  \
# 0                     2.7                 57.9                 1.9
#
#    Debt Service  Other
# 0           6.4    2.7

# %%
sns.barplot(x='county', y='health_social_services', data=response)
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3681403917.py in <cell line: 0>()
# ----> 1 sns.barplot(x='county', y='health_social_services', data=response)
#       2 plt.xticks(rotation=90)
#       3 plt.show()
#
# NameError: name 'sns' is not defined
